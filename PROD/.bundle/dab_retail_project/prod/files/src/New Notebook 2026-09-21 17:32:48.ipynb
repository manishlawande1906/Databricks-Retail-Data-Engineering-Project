# %%
# %sql
create external location `managed-location`
URL 'abfss://managed-location@retailstorageaccount19.dfs.core.windows.net/'
with (storage credential `retail_cred`)

# %%
# %sql
create catalog bundle_prod
managed location 'abfss://managed-location@retailstorageaccount19.dfs.core.windows.net/'
